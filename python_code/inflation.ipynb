# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('full_data.csv')

# %%
cpi = [296.2, 304.6, 316.3, 315.2, 320.4, 330.5, 337.5, 342.5, 348.3, 348.9, 353.4, 361.0, 369.8]
cpi_adj = [x/369.8 for x in cpi]

# %%
years = [2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018]
infl_dict = dict(zip(years, cpi_adj))

data['real_gprice']=0
for k in infl_dict:
    data.loc[data.year == k, 'real_gprice'] = data['gprice'].map(lambda x: x*infl_dict[k])
    
data.head()
# Out:
#   Total Population  Area Total:  Area (Land)  Area (Water) Total Population:  \
# 0          575,187        89.63         0.54          0.46           575,187
# 1          575,187        89.63         0.54          0.46           575,187
# 2          575,187        89.63         0.54          0.46           575,187
# 3          575,187        89.63         0.54          0.46           575,187
# 4          575,187        89.63         0.54          0.46           575,187
#
#    Less than 5 Years  Less than 10 Years  Less than 15 Years  \
# 0              0.063               0.109               0.159
# 1              0.063               0.109               0.159
# 2              0.063               0.109               0.159
# 3              0.063               0.109               0.159
# 4              0.063               0.109               0.159
#
#    Less than 18 Years  Less than 25 Years  ...  Native Born  Foreign Born:  \
# ...

# %%
data.to_csv('full_data_inflation.csv', index=False)
